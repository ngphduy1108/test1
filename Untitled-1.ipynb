# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Sales_Data.csv')
print(df.head())

# %%
def clean_currency_column(column):
    return pd.to_numeric(column.replace({'\$': '', ',': ''}, regex=True))
 
 #convert column to numeric 
df['Sales Amount'] = clean_currency_column(df['Sales Amount'])
df['Product Standard Cost'] = clean_currency_column(df['Product Standard Cost'])
df['Total Product Cost'] = clean_currency_column(df['Total Product Cost'])
df['Unit Price'] = clean_currency_column(df['Unit Price'])
df['Extended Amount'] = clean_currency_column(df['Extended Amount'])

df.drop(columns=['Unit Price Discount Pct'], inplace=True)
df.drop(columns=['DueDateKey'], inplace=True)
df.drop(columns=['OrderDateKey'], inplace=True)
df.drop(columns=['ShipDateKey'], inplace=True)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print(df.head())
# Out:
#    SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  SalesTerritoryKey  \
# 0           43659001          676           -1         349                  5
# 1           43659002          676           -1         350                  5
# 2           43659003          676           -1         351                  5
# 3           43659004          676           -1         344                  5
# 4           43659005          676           -1         345                  5
#
#    Order Quantity  Unit Price  Extended Amount  Product Standard Cost  \
# 0               1     2024.99          2024.99                1898.09
# 1               3     2024.99          6074.98                1898.09
# 2               1     2024.99          2024.99                1898.09
# 3               1     2039.99          2039.99                1912.15
# 4               1     2039.99          2039.99                1912.15
#
#    Total Product Cost  Sales Amount
# 0             1898.09       2024.99
# 1             5694.28       6074.98
# 2             1898.09       2024.99
# 3             1912.15       2039.99
# 4             1912.15       2039.99

# %%
df.isnull().sum()
# Out:
# SalesOrderLineKey        0
# ResellerKey              0
# CustomerKey              0
# ProductKey               0
# SalesTerritoryKey        0
# Order Quantity           0
# Unit Price               0
# Extended Amount          0
# Product Standard Cost    0
# Total Product Cost       0
# Sales Amount             0
# dtype: int64

# %%
df.nunique()
# Out:
# SalesOrderLineKey        121253
# ResellerKey                 636
# CustomerKey               18485
# ProductKey                  350
# SalesTerritoryKey            10
# Order Quantity               41
# Unit Price                  268
# Extended Amount            1424
# Product Standard Cost       123
# Total Product Cost         1423
# Sales Amount               1443
# dtype: int64

# %%
df.sort_values(by='Sales Amount', ascending = False).head()
# Out:
#        SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  \
# 40871           55282039          599           -1         561
# 769             43884017          623           -1         345
# 31396           51131012          599           -1         576
# 658             43875012          278           -1         348
# 42399           57054026          614           -1         573
#
#        SalesTerritoryKey  Order Quantity  Unit Price  Extended Amount  \
# 40871                  4              26     1192.04         30992.91
# 769                    3              14     1971.99         27607.92
# 31396                  4              21     1311.24         27536.01
# 658                    5              13     1957.49         25447.42
# 42399                  7              19     1311.24         24913.53
#
#        Product Standard Cost  Total Product Cost  Sales Amount
# 40871                1481.94            38530.39      27893.62
# 769                  1912.15            26770.16      27055.76
# 31396                1481.94            31120.70      26159.21
# 658                  1898.09            24675.23      24938.48
# 42399                1481.94            28156.82      23667.85

# %%
df.corr()
# Out:
#                        SalesOrderLineKey  ResellerKey  CustomerKey  \
# SalesOrderLineKey               1.000000    -0.332146     0.422380
# ResellerKey                    -0.332146     1.000000    -0.702922
# CustomerKey                     0.422380    -0.702922     1.000000
# ProductKey                      0.324203    -0.073306     0.113997
# SalesTerritoryKey               0.163289    -0.220785     0.257371
# Order Quantity                 -0.215696     0.375159    -0.468872
# Unit Price                     -0.220860    -0.017903     0.014021
# Extended Amount                -0.237622     0.191084    -0.234462
# Product Standard Cost          -0.264364     0.110557    -0.136852
# Total Product Cost             -0.226603     0.237109    -0.288873
# Sales Amount                   -0.237531     0.190171    -0.233728
#
#                        ProductKey  SalesTerritoryKey  Order Quantity  \
# SalesOrderLineKey        0.324203           0.163289       -0.215696
# ResellerKey             -0.073306          -0.220785        0.375159
# CustomerKey              0.113997           0.257371       -0.468872
# ProductKey               1.000000           0.062638       -0.077612
# SalesTerritoryKey        0.062638           1.000000       -0.134821
# Order Quantity          -0.077612          -0.134821        1.000000
# Unit Price              -0.104415           0.041098       -0.076947
# Extended Amount         -0.086438          -0.075045        0.308033
# Product Standard Cost   -0.099435          -0.018334       -0.014590
# Total Product Cost      -0.066629          -0.098707        0.347217
# Sales Amount            -0.088111          -0.075064        0.304023
#
#                        Unit Price  Extended Amount  Product Standard Cost  \
# SalesOrderLineKey       -0.220860        -0.237622              -0.264364
# ResellerKey             -0.017903         0.191084               0.110557
# CustomerKey              0.014021        -0.234462              -0.136852
# ProductKey              -0.104415        -0.086438              -0.099435
# SalesTerritoryKey        0.041098        -0.075045              -0.018334
# Order Quantity          -0.076947         0.308033              -0.014590
# Unit Price               1.000000         0.642287               0.951365
# Extended Amount          0.642287         1.000000               0.742258
# Product Standard Cost    0.951365         0.742258               1.000000
# Total Product Cost       0.514639         0.977215               0.661070
# Sales Amount             0.645849         0.999352               0.743471
#
#                        Total Product Cost  Sales Amount
# SalesOrderLineKey               -0.226603     -0.237531
# ResellerKey                      0.237109      0.190171
# CustomerKey                     -0.288873     -0.233728
# ProductKey                      -0.066629     -0.088111
# SalesTerritoryKey               -0.098707     -0.075064
# Order Quantity                   0.347217      0.304023
# Unit Price                       0.514639      0.645849
# Extended Amount                  0.977215      0.999352
# Product Standard Cost            0.661070      0.743471
# Total Product Cost               1.000000      0.971876
# Sales Amount                     0.971876      1.000000

# %%
sns.heatmap(df.corr(), annot=True)

plt.rcParams['figure.figsize'] = (20, 7)
plt.show()

# %%
df.groupby('SalesTerritoryKey').mean()
# Out:
#                    SalesOrderLineKey  ResellerKey   CustomerKey  ProductKey  \
# SalesTerritoryKey
# 1                       5.846990e+07   162.392470  10386.190987  432.231367
# 2                       5.267667e+07   358.652673     73.049863  397.124914
# 3                       5.316983e+07   394.939643     65.510288  399.515947
# 4                       5.722302e+07   145.506980   9392.113906  418.913937
# 5                       5.259904e+07   359.073461    116.771754  399.250502
# 6                       5.685619e+07   197.226972   6646.703735  418.776280
# 7                       5.962865e+07   147.714569  11617.310189  436.379842
# 8                       6.147932e+07    89.060825  14581.123794  441.657020
# 9                       6.090301e+07    43.364125  16637.977089  443.703613
# 10                      5.989784e+07   113.739306  12349.849990  434.064167
#
#                    Order Quantity  Unit Price  Extended Amount  \
# SalesTerritoryKey
# 1                        2.180611  449.406614       958.964101
# 2                        3.400103  425.338317      1193.147121
# 3                        3.342421  460.010439      1360.742848
# 4                        2.304828  459.078238       948.220947
# 5                        3.158467  486.292274      1325.394346
# 6                        2.590275  359.149854       862.417388
# 7                        2.190361  435.730619       802.318649
# 8                        1.742363  479.240833       657.657093
# 9                        1.214836  652.724663       709.514528
# 10                       1.927777  457.406238       738.810590
#
#                    Product Standard Cost  Total Product Cost  Sales Amount
# SalesTerritoryKey
# 1                             353.683012          850.544110    953.746976
# 2                             419.332377         1175.329546   1189.063509
# 3                             452.211754         1331.807560   1356.140074
# 4                             363.911681          851.212145    943.090393
# 5                             476.621831         1297.565658   1318.549967
# 6                             310.846450          805.058556    857.940128
# 7                             314.488102          682.505155    797.926459
# 8                             323.319184          509.403627    653.577185
# 9                             410.536393          470.063231    707.619576
# 10                            322.533151          601.751022    735.730014
